# %%
import pyarrow.parquet as pq

# %%
# Read
table = pq.read_table('s3://ubs-datasets/bigearthnet/metadata.parquet')
table
# Out:
# pyarrow.Table
# patch_id: string
# labels: list<element: string>
#   child 0, element: string
# split: string
# country: string
# s1_name: string
# s2v1_name: string
# contains_seasonal_snow: bool
# contains_cloud_or_shadow: bool
# ----
# patch_id: [["S2A_MSIL2A_20170613T101031_N9999_R022_T33UUP_26_57","S2A_MSIL2A_20170613T101031_N9999_R022_T33UUP_27_55","S2A_MSIL2A_20170613T101031_N9999_R022_T33UUP_27_56","S2A_MSIL2A_20170613T101031_N9999_R022_T33UUP_27_57","S2A_MSIL2A_20170613T101031_N9999_R022_T33UUP_27_58",...,"S2A_MSIL2A_20171208T093351_N9999_R136_T34TEN_67_77","S2A_MSIL2A_20171208T093351_N9999_R136_T34TEN_67_78","S2A_MSIL2A_20171208T093351_N9999_R136_T34TEN_67_79","S2A_MSIL2A_20171208T093351_N9999_R136_T34TEN_67_80","S2A_MSIL2A_20171208T093351_N9999_R136_T34TEN_67_81"],["S2A_MSIL2A_20171208T093351_N9999_R136_T34TEN_67_82","S2A_MSIL2A_20171208T093351_N9999_R136_T34TEN_67_83","S2A_MSIL2A_20171208T093351_N9999_R136_T34TEN_67_84","S2A_MSIL2A_20171208T093351_N9999_R136_T34TEN_67_85","S2A_MSIL2A_20171208T093351_N9999_R136_T34TEN_67_86",...,"S2B_MSIL2A_20170906T101019_N9999_R022_T34WFS_83_09","S2B_MSIL2A_20170906T101019_N9999_R022_T34WFS_83_10","S2B_MSIL2A_20170906T101019_N9999_R022_T34WFS_83_11","S2B_MSIL2A_20170906T101019_N9999_R022_T34WFS_83_12","S2B_MSIL2A_20170906T101019_N9999_R022_T34WFS_83_13"],["S2B_MSIL2A_20170906T101019_N9999_R022_T34WFS_83_14","S2B_MSIL2A_20170906T101019_N9999_R022_T34WFS_83_15","S2B_MSIL2A_20170906T101019_N9999_R022_T34WFS_83_16","S2B_MSIL2A_20170906T101019_N9999_R022_T34WFS_83_17","S2B_MSIL2A_20170906T101019_N9999_R022_T34WFS_83_18",...,"S2B_MSIL2A_20180417T102019_N9999_R065_T34WFV_46_41","S2B_MSIL2A_20180417T102019_N9999_R065_T34WFV_46_42","S2B_MSIL2A_20180417T102019_N9999_R065_T34WFV_46_46","S2B_MSIL2A_20180417T102019_N9999_R065_T34WFV_46_50","S2B_MSIL2A_20180417T102019_N9999_R065_T34WFV_46_51"],["S2B_MSIL2A_20180417T102019_N9999_R065_T34WFV_46_52","S2B_MSIL2A_20180417T102019_N9999_R065_T34WFV_46_55","S2B_MSIL2A_20180417T102019_N9999_R065_T34WFV_46_58","S2B_MSIL2A_20180417T102019_N9999_R065_T34WFV_46_59","S2B_MSIL2A_20180417T102019_N9999_R065_T34WFV_46_60",...,"S2B_MSIL2A_20180525T094029_N9999_R036_T35VNL_90_86","S2B_MSIL2A_20180525T094029_N9999_R036_T35VNL_90_87","S2B_MSIL2A_20180525T094029_N9999_R036_T35VNL_90_88","S2B_MSIL2A_20180525T094029_N9999_R036_T35VNL_90_89","S2B_MSIL2A_20180525T094029_N9999_R036_T35VNL_90_90"]]
# labels: [[["Arable land","Broad-leaved forest","Mixed forest","Pastures"],["Arable land","Broad-leaved forest","Inland waters","Mixed forest"],...,["Broad-leaved forest","Land principally occupied by agriculture, with significant areas of natural vegetation","Pastures","Transitional woodland, shrub"],["Broad-leaved forest","Complex cultivation patterns","Transitional woodland, shrub"]],[["Broad-leaved forest","Complex cultivation patterns","Transitional woodland, shrub"],["Broad-leaved forest","Natural grassland and sparsely vegetated areas","Transitional woodland, shrub"],...,["Broad-leaved forest","Coniferous forest","Mixed forest","Transitional woodland, shrub"],["Broad-leaved forest","Coniferous forest","Mixed forest","Transitional woodland, shrub"]],[["Coniferous forest","Inland wetlands","Mixed forest","Transitional woodland, shrub"],["Coniferous forest","Inland wetlands","Mixed forest"],...,["Coniferous forest","Inland wetlands","Transitional woodland, shrub"],["Coniferous forest","Transitional woodland, shrub"]],[["Coniferous forest","Transitional woodland, shrub"],["Coniferous forest","Transitional woodland, shrub"],...,["Coniferous forest"],["Coniferous forest","Transitional woodland, shrub"]]]
# split: [["test","test","test","test","test",...,"validation","train","train","train","train"],["train","train","train","train","train",...,"train","train","train","train","train"],["train","train","train","train","train",...,"test","test","test","test","test"],["test","test","test","test","test",...,"train","train","train","train","train"]]
# country: [["Austria","Austria","Austria","Austria","Austria",...,"Serbia","Serbia","Serbia","Serbia","Serbia"],["Serbia","Serbia","Serbia","Serbia","Serbia",...,"Finland","Finland","Finland","Finland","Finland"],["Finland","Finland","Finland","Finland","Finland",...,"Finland","Finland","Finland","Finland","Finland"],["Finland","Finland","Finland","Finland","Finland",...,"Finland","Finland","Finland","Finland","Finland"]]
# s1_name: [["S1B_IW_GRDH_1SDV_20170612T165809_33UUP_26_57","S1B_IW_GRDH_1SDV_20170612T165809_33UUP_27_55","S1B_IW_GRDH_1SDV_20170612T165809_33UUP_27_56","S1B_IW_GRDH_1SDV_20170612T165809_33UUP_27_57","S1B_IW_GRDH_1SDV_20170612T165809_33UUP_27_58",...,"S1A_IW_GRDH_1SDV_20171207T162425_34TEN_67_77","S1A_IW_GRDH_1SDV_20171207T162425_34TEN_67_78","S1A_IW_GRDH_1SDV_20171207T162425_34TEN_67_79","S1A_IW_GRDH_1SDV_20171207T162425_34TEN_67_80","S1A_IW_GRDH_1SDV_20171207T162425_34TEN_67_81"],["S1A_IW_GRDH_1SDV_20171207T162425_34TEN_67_82","S1A_IW_GRDH_1SDV_20171207T162425_34TEN_67_83","S1A_IW_GRDH_1SDV_20171207T162425_34TEN_67_84","S1A_IW_GRDH_1SDV_20171207T162425_34TEN_67
S2A_MSIL2A_20170613T101031_N9999_R022_T33UUP_2...
#
#                                               labels split  country  \
# 0  [Arable land, Broad-leaved forest, Mixed fores...  test  Austria
# 1  [Arable land, Broad-leaved forest, Inland wate...  test  Austria
# 2  [Arable land, Broad-leaved forest, Coniferous ...  test  Austria
# 3  [Broad-leaved forest, Complex cultivation patt...  test  Austria
# 4  [Broad-leaved forest, Complex cultivation patt...  test  Austria
#
#                                         s1_name  \
# 0  S1B_IW_GRDH_1SDV_20170612T165809_33UUP_26_57
# 1  S1B_IW_GRDH_1SDV_20170612T165809_33UUP_27_55
# 2  S1B_IW_GRDH_1SDV_20170612T165809_33UUP_27_56
# 3  S1B_IW_GRDH_1SDV_20170612T165809_33UUP_27_57
# 4  S1B_IW_GRDH_1SDV_20170612T165809_33UUP_27_58
#
#                           s2v1_name  contains_seasonal_snow  \
# 0  S2A_MSIL2A_20170613T101031_26_57                   False
# 1  S2A_MSIL2A_20170613T101031_27_55                   False
# 2  S2A_MSIL2A_20170613T101031_27_56                   False
# 3  S2A_MSIL2A_20170613T101031_27_57                   False
# 4  S2A_MSIL2A_20170613T101031_27_58                   False
#
#    contains_cloud_or_shadow
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False

# %%
import pyarrow.compute as pc

# Extract the prefix up to the timestamp for s1_name
s1_prefix = pc.replace_substring_regex(table['s1_name'], r'((?:[^_]+_){4}[^_]+)_.*', r'\1')

# folder S1 path column
s1_path = pc.binary_join_element_wise("s3://ubs-datasets/bigearthnet/BigEarthNet-S1/", s1_prefix, '')
s1_path_ = pc.binary_join_element_wise(s1_path, table['s1_name'], '/')

# Extract the prefix up to the timestamp for s2 (using patch_id )
s2_prefix = pc.replace_substring_regex(table['patch_id'], r'((?:[^_]+_){5}[^_]+)_.*', r'\1')

# folder s2 path column
s2_path = pc.binary_join_element_wise("s3://ubs-datasets/bigearthnet/BigEarthNet-S2/", s2_prefix,'')
s2_path_ = pc.binary_join_element_wise(s2_path, table['patch_id'], '/')

# folder reference path column
ref_path = pc.binary_join_element_wise("s3://ubs-datasets/bigearthnet/Reference_Maps/", s2_prefix, '')
ref_path_ = pc.binary_join_element_wise(ref_path, table['patch_id'], '/')

# Add new columns to the table
table = table.append_column('s1_path', s1_path_)
table = table.append_column('s2_path', s2_path_)
table = table.append_column('reference_path', ref_path_)

# %%
pandas_df = table.to_pandas()
pandas_df.head()
# Out:
#                                             patch_id  \
# 0  S2A_MSIL2A_20170613T101031_N9999_R022_T33UUP_2...
# 1  S2A_MSIL2A_20170613T101031_N9999_R022_T33UUP_2...
# 2  S2A_MSIL2A_20170613T101031_N9999_R022_T33UUP_2...
# 3  S2A_MSIL2A_20170613T101031_N9999_R022_T33UUP_2...
# 4  S2A_MSIL2A_20170613T101031_N9999_R022_T33UUP_2...
#
#                                               labels split  country  \
# 0  [Arable land, Broad-leaved forest, Mixed fores...  test  Austria
# 1  [Arable land, Broad-leaved forest, Inland wate...  test  Austria
# 2  [Arable land, Broad-leaved forest, Coniferous ...  test  Austria
# 3  [Broad-leaved forest, Complex cultivation patt...  test  Austria
# 4  [Broad-leaved forest, Complex cultivation patt...  test  Austria
#
#                                         s1_name  \
# 0  S1B_IW_GRDH_1SDV_20170612T165809_33UUP_26_57
# 1  S1B_IW_GRDH_1SDV_20170612T165809_33UUP_27_55
# 2  S1B_IW_GRDH_1SDV_20170612T165809_33UUP_27_56
# 3  S1B_IW_GRDH_1SDV_20170612T165809_33UUP_27_57
# 4  S1B_IW_GRDH_1SDV_20170612T165809_33UUP_27_58
#
#                           s2v1_name  contains_seasonal_snow  \
# 0  S2A_MSIL2A_20170613T101031_26_57                   False
# 1  S2A_MSIL2A_20170613T101031_27_55                   False
# 2  S2A_MSIL2A_20170613T101031_27_56                   False
# 3  S2A_MSIL2A_20170613T101031_27_57                   False
# 4  S2A_MSIL2A_20170613T101031_27_58                   False
#
#    contains_cloud_or_shadow  \
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
#                                              s1_path  \
# 0  s3://ubs-datasets/bigearthnet/BigEarthNet-S1/S...
# 1  s3://ubs-datasets/bigearthnet/BigEarthNet-S1/S...
# 2  s3://ubs-datasets/bigearthnet/BigEarthNet-S1/S...
# 3  s3://ubs-datasets/bigearthnet/BigEarthNet-S1/S...
# 4  s3://ubs-datasets/bigearthnet/BigEarthNet-S1/S...
#
#                                              s2_path  \
# 0  s3://ubs-datasets/bigearthnet/BigEarthNet-S2/S...
# 1  s3://ubs-datasets/bigearthnet/BigEarthNet-S2/S...
# 2  s3://ubs-datasets/bigearthnet/BigEarthNet-S2/S...
# 3  s3://ubs-datasets/bigearthnet/BigEarthNet-S2/S...
# 4  s3://ubs-datasets/bigearthnet/BigEarthNet-S2/S...
#
#                                       reference_path  \
# 0  s3://ubs-datasets/bigearthnet/BigEarthNet/Refe...
# 1  s3://ubs-datasets/bigearthnet/BigEarthNet/Refe...
# 2  s3://ubs-datasets/bigearthnet/BigEarthNet/Refe...
# 3  s3://ubs-datasets/bigearthnet/BigEarthNet/Refe...
# 4  s3://ubs-datasets/bigearthnet/BigEarthNet/Refe...
#
#                                              s1_path  \
# 0  s3://ubs-datasets/bigearthnet/BigEarthNet-S1/S...
# 1  s3://ubs-datasets/bigearthnet/BigEarthNet-S1/S...
# 2  s3://ubs-datasets/bigearthnet/BigEarthNet-S1/S...
# 3  s3://ubs-datasets/bigearthnet/BigEarthNet-S1/S...
# 4  s3://ubs-datasets/bigearthnet/BigEarthNet-S1/S...
#
#                                              s2_path  \
# 0  s3://ubs-datasets/bigearthnet/BigEarthNet-S2/S...
# 1  s3://ubs-datasets/bigearthnet/BigEarthNet-S2/S...
# 2  s3://ubs-datasets/bigearthnet/BigEarthNet-S2/S...
# 3  s3://ubs-datasets/bigearthnet/BigEarthNet-S2/S...
# 4  s3://ubs-datasets/bigearthnet/BigEarthNet-S2/S...
#
#                                       reference_path
# 0  s3://ubs-datasets/bigearthnet/Reference_Maps/S...
# 1  s3://ubs-datasets/bigearthnet/Reference_Maps/S...
# 2  s3://ubs-datasets/bigearthnet/Reference_Maps/S...
# 3  s3://ubs-datasets/bigearthnet/Reference_Maps/S...
# 4  s3://ubs-datasets/bigearthnet/Reference_Maps/S...

# %%
# save
pq.write_table(table, 's3://ubs-homes/erasmus/ethel/bigearth/metadata.parquet')

# %% [markdown]
# #### lets check if the folder structure produced are right and exists

# %%
import boto3

s3_client = boto3.client('s3')

def check_s3_folder_exists(s3_path):
    if not s3_path or not isinstance(s3_path, str) or not s3_path.startswith('s3://'):
        return False
    
    path_parts = s3_path.replace('s3://', '').split('/', 1)
    bucket = path_parts[0]
    prefix = path_parts[1] if len(path_parts) > 1 else ''
    
    if not prefix.endswith('/'):
        prefix += '/'
    
    response = s3_client.list_objects_v2(Bucket=bucket, Prefix=prefix, MaxKeys=1)
    return 'Contents' in response

df = table.to_pandas()

for idx in range(min(5, len(df))):
    row = df.iloc[idx]
    
    s1_exists = check_s3_folder_exists(row['s1_path'])
    s2_exists = check_s3_folder_exists(row['s2_path'])
    ref_exists = check_s3_folder_exists(row['reference_path'])
    
    print(f"Row {idx}:")
    print(f"  S1 path: {row['s1_path']} - {'EXISTS' if s1_exists else 'NOT FOUND'}")
    print(f"  S2 path: {row['s2_path']} - {'EXISTS' if s2_exists else 'NOT FOUND'}")
    print(f"  Ref path: {row['reference_path']} - {'EXISTS' if ref_exists else 'NOT FOUND'}")
    print()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/8h/9b5vjqfx7rx6mwssqpkqv8fr0000gn/T/ipykernel_11400/2062366144.py in ?()
#      20
#      21 for idx in range(min(5, len(df))):
#      22     row = df.iloc[idx]
#      23
# ---> 24     s1_exists = check_s3_folder_exists(row['s1_path'])
#      25     s2_exists = check_s3_folder_exists(row['s2_path'])
#      26     ref_exists = check_s3_folder_exists(row['reference_path'])
#      27
#
# /var/folders/8h/9b5vjqfx7rx6mwssqpkqv8fr0000gn/T/ipykernel_11400/2062366144.py in ?(s3_path)
#       5 def check_s3_folder_exists(s3_path):
# ----> 6     if not s3_path or not isinstance(s3_path, str) or not s3_path.startswith('s3://'):
#       7         return False
#       8
#       9     path_parts = s3_path.replace('s3://', '').split('/', 1)
#
# ~/academia/bigearthnet-dl-distributed/.venv/lib/python3.12/site-packages/pandas/core/generic.py in ?(self)
#    1578     @final
#    1579     def __nonzero__(self) -> NoReturn:
# -> 1580         raise ValueError(
#    1581             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1582             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1583         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
